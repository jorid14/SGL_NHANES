# %% [markdown]
# **Objectives**
#
# Provide statistical distribution plots of FPED components, for comparison on how they are distributed among the seafood vs non-seafood meals.

# %% [markdown]
# **Applied Data Filters**
#
# The dataframe included in this analysis contains the following modifications of the original data set:
#
# 1. Meal level aggregation
# 2. Meals that are only lunch or dinner
# 3. Meals that have both seafood and meat, where there is ambiguity in the ratio, are dropped
# 4. Meals that are more than 0 KCAL
# 5. Meals of participants older than 18 years of age
# 6. Meals that are consumed at home
# 7. Meals that are non-vegeterian

# %% [markdown]
# **Section 1: Fruits**
#
# This section provides boxplots and density plots of the Fruit FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %%
import pandas as pd

#Read data frame and add plant pf total variable
df = pd.read_csv('../../Data/nhanes_full_pre_proc.csv')

# %%
import matplotlib.pyplot as plt

fruits = ['F_TOTAL', 'F_CITMLB', 'F_OTHER', 'F_JUICE']

for var in fruits:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
for var in fruits:
    z = df.groupby('seafood_meal')[var].plot.kde(title = var, legend='x')
    plt.show(z[0].set_xlim(0, 0.3))
    plt.clf()

# %%
for var in fruits:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for F_TOTAL
#
#                 count      mean       std  min  25%  50%   75%    max
# seafood_meal
# 0             26011.0  0.148838  0.491428  0.0  0.0  0.0  0.00  19.64
# 1              3232.0  0.187642  0.513770  0.0  0.0  0.0  0.03   5.08
#
#
# Statistics for F_CITMLB
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.029057  0.239037  0.0  0.0  0.0  0.0  18.94
# 1              3232.0  0.043815  0.255454  0.0  0.0  0.0  0.0   4.55
#
#
# Statistics for F_OTHER
#
#                 count      mean       std  min  25%  50%  75%   max
# seafood_meal
# 0             26011.0  0.054642  0.249359  0.0  0.0  0.0  0.0  6.09
# 1              3232.0  0.069378  0.293768  0.0  0.0  0.0  0.0  4.37
#
#
# Statistics for F_JUICE
#
#                 count      mean       std  min  25%  50%  75%   max
# seafood_meal
# 0             26011.0  0.065132  0.322374  0.0  0.0  0.0  0.0  7.97
# ...

# %% [markdown]
# **Fruits Within Seafood Species**

# %%
for var in fruits:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
species_filter = ['salmon', 'tuna-mixed', 'tuna-fresh', 'shrimp', 'cod']

df_species = df[df['species'].isin(species_filter)]

for var in fruits:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in fruits:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for F_TOTAL
#
#              count      mean       std   min     25%    50%     75%   max
# species
# snails         3.0  1.306667  2.263213  0.00  0.0000  0.000  1.9600  3.92
# eel            6.0  0.488333  0.722729  0.00  0.0000  0.085  0.8375  1.70
# squid         23.0  0.480000  0.874383  0.00  0.0000  0.000  0.4900  2.69
# sea bass      22.0  0.405909  1.133972  0.00  0.0000  0.005  0.0375  4.95
# lobster       20.0  0.344500  0.571696  0.00  0.0000  0.010  0.5800  1.91
# mackerel      20.0  0.340000  0.617721  0.00  0.0000  0.000  0.2875  1.77
# sardines      42.0  0.334048  0.634370  0.00  0.0000  0.000  0.4000  2.17
# shellfish     15.0  0.318667  0.678979  0.00  0.0000  0.000  0.3250  2.48
# crayfish      11.0  0.305455  0.677294  0.00  0.0000  0.000  0.0400  1.98
# porgy         25.0  0.289200  0.927420  0.00  0.0000  0.000  0.0000  4.32
# tuna-fresh    37.0  0.274054  0.775061  0.00  0.0000  0.000  0.0500  4.28
# ...

# %% [markdown]
# **Section 2: Vegetables**
#
# This section provides boxplots and density plots of the Vegetable FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %%
veggie = ['V_TOTAL', 'V_DRKGR', 'V_REDOR_TOMATO', 'V_REDOR_OTHER', 'V_STARCHY_POTATO', 
                   'V_STARCHY_OTHER', 'V_OTHER', 'V_LEGUMES']

for var in veggie:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[0]].plot.kde(title = veggie[0], legend='x')
plt.show(z[0].set_xlim(0, 3))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[1]].plot.kde(title = veggie[1], legend='x')
plt.show(z[0].set_xlim(0, 0.15))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[2]].plot.kde(title = veggie[2], legend='x')
plt.show(z[0].set_xlim(0, 0.2))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[3]].plot.kde(title = veggie[3], legend='x')
plt.show(z[0].set_xlim(0, 0.1))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[4]].plot.kde(title = veggie[4], legend='x')
plt.show(z[0].set_xlim(0, 0.2))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[5]].plot.kde(title = veggie[5], legend='x')
plt.show(z[0].set_xlim(0, 0.1))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[6]].plot.kde(title = veggie[6], legend='x')
plt.show(z[0].set_xlim(0, 1))
plt.clf()

# %%
z = df.groupby('seafood_meal')[veggie[7]].plot.kde(title = veggie[7], legend='x')
plt.show(z[0].set_xlim(0, 0.1))
plt.clf()

# %%
for var in veggie:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for V_TOTAL
#
#                 count      mean       std  min   25%   50%   75%    max
# seafood_meal
# 0             26011.0  0.766811  0.830492  0.0  0.13  0.54  1.12  11.97
# 1              3232.0  0.839502  0.884815  0.0  0.17  0.61  1.23   9.40
#
#
# Statistics for V_DRKGR
#
#                 count      mean       std  min  25%  50%  75%   max
# seafood_meal
# 0             26011.0  0.064261  0.248228  0.0  0.0  0.0  0.0  3.99
# 1              3232.0  0.133026  0.378411  0.0  0.0  0.0  0.0  4.78
#
#
# Statistics for V_REDOR_TOMATO
#
#                 count      mean       std  min  25%   50%   75%   max
# seafood_meal
# 0             26011.0  0.155829  0.280726  0.0  0.0  0.01  0.22  5.03
# 1              3232.0  0.096572  0.217002  0.0  0.0  0.00  0.09  3.31
#
#
# Statistics for V_REDOR_OTHER
#
#                 count      mean       std  min  25%  50%  75%   max
# seafood_meal
# 0             26011.0  0.044952  0.150933  0.0  0.0  0.0  0.0  3.97
# ...

# %% [markdown]
# **Vegetables Within Seafood Species**

# %%
for var in veggie:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in veggie:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in veggie:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for V_TOTAL
#
#              count      mean       std   min     25%    50%     75%   max
# species
# pike           2.0  3.115000  0.530330  2.74  2.9275  3.115  3.3025  3.49
# shad           1.0  2.210000       NaN  2.21  2.2100  2.210  2.2100  2.21
# carp          15.0  1.622667  2.435782  0.00  0.1800  0.890  1.6200  9.40
# swordfish     10.0  1.537000  1.068239  0.00  0.6375  1.745  2.3450  2.91
# eel            6.0  1.301667  0.539385  0.68  0.9050  1.215  1.7800  1.93
# ocean perch   23.0  1.292609  1.016313  0.00  0.4400  1.080  2.2550  3.16
# scallops      12.0  1.284167  0.835610  0.00  0.7325  1.160  1.5375  3.11
# shellfish     15.0  1.269333  1.228661  0.24  0.5500  0.790  1.6350  5.00
# sea bass      22.0  1.268182  1.009760  0.00  0.6000  1.035  1.7300  3.56
# snails         3.0  1.223333  1.236177  0.31  0.5200  0.730  1.6800  2.63
# lobster       20.0  1.129500  0.753794  0.00  0.6575  1.170  1.7550  2.47
# ...

# %% [markdown]
# **Section 3: Grains**
#
# This section provides boxplots and density plots of the Grains FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %% [markdown]
# Plot: Meal calories distribution with meals that are 0 KCAL removed, split by 'eathome' groups.

# %%
grains = ['G_TOTAL', 'G_WHOLE','G_REFINED']

for var in grains:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
z = df.groupby('seafood_meal')[grains[0]].plot.kde(title = grains[0], legend='x')
plt.show(z[0].set_xlim(0, 10))
plt.clf()

# %%
z = df.groupby('seafood_meal')[grains[1]].plot.kde(title = grains[1], legend='x')
plt.show(z[0].set_xlim(0, 0.3))
plt.clf()

# %%
z = df.groupby('seafood_meal')[grains[2]].plot.kde(title = grains[2], legend='x')
plt.show(z[0].set_xlim(0, 10))
plt.clf()

# %%
for var in grains:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for G_TOTAL
#
#                 count      mean       std  min   25%   50%     75%    max
# seafood_meal
# 0             26011.0  2.480072  2.398177  0.0  0.94  1.95  3.3200  28.83
# 1              3232.0  2.053747  1.958012  0.0  0.67  1.75  2.7825  19.26
#
#
# Statistics for G_WHOLE
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.158145  0.580842  0.0  0.0  0.0  0.0  17.79
# 1              3232.0  0.184836  0.620747  0.0  0.0  0.0  0.0   9.65
#
#
# Statistics for G_REFINED
#
#                 count      mean      std  min   25%   50%     75%    max
# seafood_meal
# 0             26011.0  2.321905  2.39243  0.0  0.74  1.76  3.1600  28.83
# 1              3232.0  1.868917  1.93630  0.0  0.36  1.46  2.6025  19.26

# %% [markdown]
# **Grains Within Seafood Species**

# %%
for var in grains:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in grains:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in grains:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for G_TOTAL
#
#              count      mean       std   min     25%    50%     75%    max
# species
# anchovy        9.0  3.367778  3.654883  0.81  1.4800  2.370  3.4100  12.79
# carp          15.0  3.352667  3.712222  0.00  0.5550  2.080  5.5500  12.84
# snails         3.0  3.186667  1.571507  2.05  2.2900  2.530  3.7550   4.98
# eel            6.0  2.915000  1.744623  1.70  2.0550  2.275  2.7200   6.39
# mussels        7.0  2.662857  4.257592  0.00  0.0000  1.660  2.5100  11.96
# croaker       24.0  2.653333  2.936426  0.00  0.8700  2.145  3.0025  13.15
# shad           1.0  2.650000       NaN  2.65  2.6500  2.650  2.6500   2.65
# tuna-fresh    37.0  2.612432  1.884827  0.00  1.1300  2.490  3.4400   6.99
# whiting       42.0  2.519762  2.013474  0.00  0.9400  2.380  3.3250   6.87
# shellfish     15.0  2.511333  1.950428  0.47  1.1250  2.000  3.6700   6.42
# catfish      140.0  2.444857  2.315237  0.00  0.8700  1.970  3.1825  12.84
# ...

# %% [markdown]
# **Section 4: Non-Meat Proteins**
#
# This section provides boxplots and density plots of the non-meat protein FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %%
non_meat_protein = ['PF_EGGS', 'PF_SOY', 'PF_NUTSDS', 'PF_LEGUMES']

for var in non_meat_protein:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
for var in non_meat_protein:
    z = df.groupby('seafood_meal')[var].plot.kde(title = var, legend='x')
    plt.show(z[0].set_xlim(0, 0.3))
    plt.clf()

# %%
for var in non_meat_protein:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for PF_EGGS
#
#                 count      mean       std  min  25%   50%   75%   max
# seafood_meal
# 0             26011.0  0.092293  0.356726  0.0  0.0  0.00  0.02  9.60
# 1              3232.0  0.143728  0.324184  0.0  0.0  0.01  0.15  4.62
#
#
# Statistics for PF_SOY
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.009890  0.136564  0.0  0.0  0.0  0.0  11.91
# 1              3232.0  0.021417  0.164274  0.0  0.0  0.0  0.0   3.97
#
#
# Statistics for PF_NUTSDS
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.046389  0.508116  0.0  0.0  0.0  0.0  48.00
# 1              3232.0  0.066460  0.493075  0.0  0.0  0.0  0.0  13.14
#
#
# Statistics for PF_LEGUMES
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.282282  1.000122  0.0  0.0  0.0  0.0  16.18
# ...

# %% [markdown]
# **Non-Meat Proteins Within Seafood Species**

# %%
for var in non_meat_protein:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in non_meat_protein:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in non_meat_protein:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for PF_EGGS
#
#              count      mean       std   min     25%    50%     75%   max
# species
# shad           1.0  0.510000       NaN  0.51  0.5100  0.510  0.5100  0.51
# anchovy        9.0  0.386667  0.696850  0.00  0.0000  0.000  0.4800  2.00
# mullet         4.0  0.365000  0.270863  0.00  0.2775  0.405  0.4925  0.65
# carp          15.0  0.351333  0.489794  0.00  0.0000  0.110  0.6850  1.51
# pike           2.0  0.320000  0.452548  0.00  0.1600  0.320  0.4800  0.64
# frog           1.0  0.300000       NaN  0.30  0.3000  0.300  0.3000  0.30
# catfish      140.0  0.275000  0.385286  0.00  0.0000  0.120  0.3400  2.22
# snails         3.0  0.230000  0.381182  0.00  0.0100  0.020  0.3450  0.67
# scallops      12.0  0.226667  0.259452  0.00  0.0550  0.140  0.3325  0.90
# perch         53.0  0.221509  0.259425  0.00  0.0000  0.160  0.3200  1.03
# flounder      61.0  0.211639  0.258658  0.00  0.0000  0.150  0.3200  0.98
# ...

# %% [markdown]
# **Section 5: Dairy**
#
# This section provides boxplots and density plots of the dairy FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %%
dairy = ['D_TOTAL', 'D_MILK', 'D_YOGURT', 'D_CHEESE']

for var in dairy:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
z = df.groupby('seafood_meal')[dairy[0]].plot.kde(title = dairy[0], legend='x')
plt.show(z[0].set_xlim(0, 1))
plt.clf()

# %%
z = df.groupby('seafood_meal')[dairy[1]].plot.kde(title = dairy[1], legend='x')
plt.show(z[0].set_xlim(0, 0.3))
plt.clf()

# %%
z = df.groupby('seafood_meal')[dairy[2]].plot.kde(title = dairy[2], legend='x')
plt.show(z[0].set_xlim(0, 0.05))
plt.clf()

# %%
z = df.groupby('seafood_meal')[dairy[3]].plot.kde(title = dairy[3], legend='x')
plt.show(z[0].set_xlim(0, 0.3))
plt.clf()

# %%
for var in dairy:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for D_TOTAL
#
#                 count      mean       std  min  25%   50%   75%    max
# seafood_meal
# 0             26011.0  0.443461  0.764443  0.0  0.0  0.06  0.65  10.76
# 1              3232.0  0.209084  0.490321  0.0  0.0  0.00  0.15   5.07
#
#
# Statistics for D_MILK
#
#                 count      mean       std  min  25%  50%   75%   max
# seafood_meal
# 0             26011.0  0.136574  0.428739  0.0  0.0  0.0  0.04  8.04
# 1              3232.0  0.111470  0.365981  0.0  0.0  0.0  0.02  5.07
#
#
# Statistics for D_YOGURT
#
#                 count      mean       std  min  25%  50%  75%   max
# seafood_meal
# 0             26011.0  0.004826  0.059659  0.0  0.0  0.0  0.0  2.68
# 1              3232.0  0.004947  0.052113  0.0  0.0  0.0  0.0  1.02
#
#
# Statistics for D_CHEESE
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# 0             26011.0  0.299695  0.623149  0.0  0.0  0.0  0.4  10.71
# ...

# %% [markdown]
# **Dairy Within Seafood Species**

# %%
for var in dairy:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in dairy:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in dairy:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for D_TOTAL
#
#              count      mean       std   min     25%    50%     75%   max
# species
# sturgeon       2.0  1.600000  1.640488  0.44  1.0200  1.600  2.1800  2.76
# clam          59.0  0.776441  1.012768  0.00  0.0400  0.470  0.9950  4.68
# shad           1.0  0.680000       NaN  0.68  0.6800  0.680  0.6800  0.68
# mussels        7.0  0.487143  1.211345  0.00  0.0000  0.000  0.0900  3.23
# anchovy        9.0  0.377778  1.023008  0.00  0.0000  0.000  0.1200  3.10
# scallops      12.0  0.365000  0.656139  0.00  0.0000  0.040  0.5025  2.23
# perch         53.0  0.325094  0.544626  0.00  0.0000  0.050  0.2500  2.19
# octopus        6.0  0.318333  0.779754  0.00  0.0000  0.000  0.0000  1.91
# lobster       20.0  0.313500  0.695938  0.00  0.0000  0.000  0.2175  2.56
# haddock       29.0  0.279655  0.536546  0.00  0.0000  0.010  0.2000  2.19
# tuna-mixed   531.0  0.279435  0.544429  0.00  0.0000  0.000  0.3200  4.17
# ...

# %% [markdown]
# **Section 6: Others**
#
# This section provides boxplots and density plots of the other FPED components in the seafood meal and non seafood meal groups. The code for seafood meal is 1 if meal contains seafood, and 0 if meal does not contain seafood.

# %%
other = ['OILS', 'SOLID_FATS', 'ADD_SUGARS', 'A_DRINKS']

for var in other:
    z = df.boxplot(column=var,by=['seafood_meal'])
    plt.show(z)
    plt.clf()

# %%
z = df.groupby('seafood_meal')[other[0]].plot.kde(title = other[0], legend='x')
plt.show(z[0].set_xlim(0, 30))
plt.clf()

# %%
z = df.groupby('seafood_meal')[other[1]].plot.kde(title = other[1], legend='x')
plt.show(z[0].set_xlim(0, 30))
plt.clf()

# %%
z = df.groupby('seafood_meal')[other[2]].plot.kde(title = other[2], legend='x')
plt.show(z[0].set_xlim(0, 10))
plt.clf()

# %%
z = df.groupby('seafood_meal')[other[3]].plot.kde(title = other[3], legend='x')
plt.show(z[0].set_xlim(0, 0.3))
plt.clf()

# %%
for var in other:
    z = df.groupby('seafood_meal')[var].describe()
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for OILS
#
#                 count       mean        std  min   25%   50%      75%     max
# seafood_meal
# 0             26011.0   8.186339  10.844504  0.0  1.23  4.51  11.3700  271.03
# 1              3232.0  11.997413  13.827625  0.0  2.74  7.84  16.3275  117.17
#
#
# Statistics for SOLID_FATS
#
#                 count       mean        std  min   25%    50%    75%     max
# seafood_meal
# 0             26011.0  13.294004  14.985754  0.0  2.77  9.000  18.83  194.29
# 1              3232.0   7.082955  11.323490  0.0  0.02  2.535   9.24  119.91
#
#
# Statistics for ADD_SUGARS
#
#                 count      mean       std  min  25%   50%   75%     max
# seafood_meal
# 0             26011.0  3.867824  5.930227  0.0  0.1  1.12  5.92  120.61
# 1              3232.0  2.961179  4.698025  0.0  0.0  0.75  4.01   61.64
#
#
# Statistics for A_DRINKS
#
#                 count      mean       std  min  25%  50%  75%    max
# seafood_meal
# ...

# %% [markdown]
# **Others Within Seafood Species**

# %%
for var in other:
    z = df.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in other:
    z = df_species.boxplot(column=var,by=['species'], rot=90)
    plt.show(z)
    plt.clf()

# %%
for var in other:
    z = df.groupby('species')[var].describe()
    z = z.sort_values(by='mean', ascending = False)
    print("Statistics for "+var+'\n')
    print(z)
    print('\n')
# Out:
# Statistics for OILS
#
#              count       mean        std    min      25%     50%      75%  \
# species
# frog           1.0  33.960000        NaN  33.96  33.9600  33.960  33.9600
# mullet         4.0  28.000000  12.759668  14.31  21.3450  26.465  33.1200
# carp          15.0  27.330000  31.294143   0.00   2.8250   8.330  51.5150
# pike           2.0  23.800000  13.039049  14.58  19.1900  23.800  28.4100
# catfish      140.0  19.656357  22.252510   0.00   4.3900  12.010  25.0775
# trout         38.0  18.449737  20.773125   0.00   4.8025  10.520  23.9450
# ocean perch   23.0  17.431739  15.073127   0.00   5.6550  14.220  26.0150
# whiting       42.0  17.207619  14.118937   0.00   6.1725  14.680  25.6400
# pompano       25.0  16.174000  17.618084   0.43   4.4700  10.820  21.0800
# flounder      61.0  15.602787  15.641196   0.00   3.7400   9.420  23.1700
# tuna-mixed   531.0  14.927552  14.787926   0.00   4.2650  11.010  20.2850
# ...
